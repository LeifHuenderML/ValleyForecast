# %%
from slstm import sLSTM
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import numpy as np
import time

def trainer(model, epochs, train_loader, val_loader, loss_fn, optim):
    train_losses = []
    val_losses = []
    best_train_loss = float('inf')
    best_val_loss = float('inf')
    best_train_epoch = 0
    best_val_epoch = 0

    for epoch in range(1, epochs+1):
        # Training
        model.train()
        num_batches = len(train_loader)
        total_train_loss = 0
        for x, y in train_loader:
            x, y = x.to('cuda'), y.to('cuda')
            output = model(x)
            loss = loss_fn(output, y)
            optim.zero_grad()
            loss.backward()
            optim.step()
            total_train_loss += loss.item()
        
        avg_train_loss = np.sqrt(total_train_loss / num_batches)
        train_losses.append(avg_train_loss)
        
        if avg_train_loss < best_train_loss:
            best_train_loss = avg_train_loss
            best_train_epoch = epoch

        # Validation
        model.eval()
        num_val_batches = len(val_loader)
        total_val_loss = 0
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to('cuda'), y.to('cuda')
                output = model(x)
                loss = loss_fn(output, y)
                total_val_loss += loss.item()
        
        avg_val_loss = np.sqrt(total_val_loss / num_val_batches)
        val_losses.append(avg_val_loss)
        
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_val_epoch = epoch

        print(f'Epoch {epoch} Train RMSE Loss: {avg_train_loss:.4f}, Val RMSE Loss: {avg_val_loss:.4f}')

        # Save results to a .txt file
        with open('test_2_round_3_training_results.txt', 'w') as f:
            f.write(f'Best Training RMSE Loss: {best_train_loss:.4f} at epoch {best_train_epoch}\n')
            f.write(f'Best Validation RMSE Loss: {best_val_loss:.4f} at epoch {best_val_epoch}\n')
            f.write('\nEpoch-wise losses:\n')
            for epoch, (train_loss, val_loss) in enumerate(zip(train_losses, val_losses), 1):
                f.write(f'Epoch {epoch}: Train RMSE = {train_loss:.4f}, Val RMSE = {val_loss:.4f}\n')

    return train_losses, val_losses, best_train_loss, best_val_loss, best_train_epoch, best_val_epoch


train = torch.load('../../../../data/cleaned/train.pt')
val = torch.load('../../../../data/cleaned/val.pt')
batch_size = 32
train_loader = DataLoader(train, batch_size, shuffle=True, drop_last=True)
val_loader = DataLoader(val, batch_size=32, shuffle=True, drop_last=True)
model = sLSTM(hidden_size=512)
model.to('cuda')
loss_fn = torch.nn.MSELoss()
optim = torch.optim.Adam(params=model.parameters(), lr=0.001)

start = time.time()
losses = trainer(model, 1000, train_loader, val_loader, loss_fn, optim)
end = time.time()

print(f'\nTotal training time on 100 epochs: {end-start}')
# Out:
# Epoch 1 Train RMSE Loss: 286.7381, Val RMSE Loss: 91.5900
# Epoch 2 Train RMSE Loss: 283.0928, Val RMSE Loss: 143.7112
# Epoch 3 Train RMSE Loss: 281.9990, Val RMSE Loss: 146.5732
# Epoch 4 Train RMSE Loss: 278.8869, Val RMSE Loss: 148.4795
# Epoch 5 Train RMSE Loss: 277.0889, Val RMSE Loss: 167.8414
# Epoch 6 Train RMSE Loss: 275.4948, Val RMSE Loss: 137.2697
# Epoch 7 Train RMSE Loss: 272.6938, Val RMSE Loss: 172.8381
# Epoch 8 Train RMSE Loss: 268.8677, Val RMSE Loss: 152.7639
# Epoch 9 Train RMSE Loss: 271.4347, Val RMSE Loss: 97.6947
# Epoch 10 Train RMSE Loss: 269.8340, Val RMSE Loss: 134.2257
# Epoch 11 Train RMSE Loss: 276.0935, Val RMSE Loss: 133.5127
# Epoch 12 Train RMSE Loss: 269.8443, Val RMSE Loss: 176.5813
# Epoch 13 Train RMSE Loss: 254.1788, Val RMSE Loss: 192.2868
# Epoch 14 Train RMSE Loss: 249.7128, Val RMSE Loss: 207.3008
# Epoch 15 Train RMSE Loss: 239.8882, Val RMSE Loss: 397.4180
# Epoch 16 Train RMSE Loss: 250.3219, Val RMSE Loss: 251.1933
# Epoch 17 Train RMSE Loss: 252.6751, Val RMSE Loss: 194.1292
# Epoch 18 Train RMSE Loss: 239.4400, Val RMSE Loss: 367.5971
# Epoch 19 Train RMSE Loss: 251.0309, Val RMSE Loss: 108.5684
# Epoch 20 Train RMSE Loss: 242.0285, Val RMSE Loss: 182.1328
# Epoch 21 Train RMSE Loss: 245.0376, Val RMSE Loss: 260.9239
# Epoch 22 Train RMSE Loss: 241.2948, Val RMSE Loss: 193.7970
# Epoch 23 Train RMSE Loss: 237.8622, Val RMSE Loss: 200.5839
# Epoch 24 Train RMSE Loss: 249.9188, Val RMSE Loss: 348.5012
# Epoch 25 Train RMSE Loss: 226.7719, Val RMSE Loss: 376.9825
# Epoch 26 Train RMSE Loss: 237.4824, Val RMSE Loss: 147.5572
# Epoch 27 Train RMSE Loss: 228.1580, Val RMSE Loss: 353.0376
# Epoch 28 Train RMSE Loss: 211.8727, Val RMSE Loss: 371.9632
# Epoch 29 Train RMSE Loss: 220.3667, Val RMSE Loss: 344.7482
# Epoch 30 Train RMSE Loss: 213.7866, Val RMSE Loss: 322.5598
# Epoch 31 Train RMSE Loss: 164.7699, Val RMSE Loss: 266.8143
# Epoch 32 Train RMSE Loss: 185.4532, Val RMSE Loss: 256.8046
# Epoch 33 Train RMSE Loss: 141.5867, Val RMSE Loss: 353.0734
# Epoch 34 Train RMSE Loss: 126.9116, Val RMSE Loss: 344.8504
# Epoch 35 Train RMSE Loss: 224.6389, Val RMSE Loss: 291.1526
# Epoch 36 Train RMSE Loss: 186.0824, Val RMSE Loss: 269.5207
# Epoch 37 Train RMSE Loss: 120.7338, Val RMSE Loss: 359.9171
# Epoch 38 Train RMSE Loss: 102.2122, Val RMSE Loss: 307.4710
# Epoch 39 Train RMSE Loss: 100.6441, Val RMSE Loss: 406.1661
# Epoch 40 Train RMSE Loss: 91.7920, Val RMSE Loss: 366.7792
# Epoch 41 Train RMSE Loss: 82.8375, Val RMSE Loss: 360.3430
# Epoch 42 Train RMSE Loss: 77.9907, Val RMSE Loss: 292.7558
# Epoch 43 Train RMSE Loss: 82.7503, Val RMSE Loss: 394.4631
# Epoch 44 Train RMSE Loss: 67.1175, Val RMSE Loss: 296.4822
# Epoch 45 Train RMSE Loss: 55.2676, Val RMSE Loss: 306.1548
# Epoch 46 Train RMSE Loss: 53.4676, Val RMSE Loss: 319.7469
# Epoch 47 Train RMSE Loss: 49.7574, Val RMSE Loss: 271.9758
# Epoch 48 Train RMSE Loss: 47.5904, Val RMSE Loss: 229.0309
# Epoch 49 Train RMSE Loss: 48.3491, Val RMSE Loss: 305.0630
# Epoch 50 Train RMSE Loss: 46.3480, Val RMSE Loss: 341.7378
# Epoch 51 Train RMSE Loss: 61.2825, Val RMSE Loss: 282.0930
# Epoch 52 Train RMSE Loss: 41.0660, Val RMSE Loss: 297.3663
# Epoch 53 Train RMSE Loss: 42.0512, Val RMSE Loss: 322.1974
# Epoch 54 Train RMSE Loss: 59.7835, Val RMSE Loss: 271.2557
# Epoch 55 Train RMSE Loss: 39.8348, Val RMSE Loss: 286.9205
# Epoch 56 Train RMSE Loss: 34.4706, Val RMSE Loss: 297.7561
# Epoch 57 Train RMSE Loss: 39.3150, Val RMSE Loss: 327.1909
# Epoch 58 Train RMSE Loss: 56.9578, Val RMSE Loss: 269.2390
# Epoch 59 Train RMSE Loss: 35.8816, Val RMSE Loss: 217.0326
# Epoch 60 Train RMSE Loss: 30.7848, Val RMSE Loss: 206.8743
# Epoch 61 Train RMSE Loss: 31.8295, Val RMSE Loss: 278.7753
# Epoch 62 Train RMSE Loss: 38.9566, Val RMSE Loss: 123.7542
# Epoch 63 Train RMSE Loss: 31.1238, Val RMSE Loss: 363.4659
# Epoch 64 Train RMSE Loss: 65.2025, Val RMSE Loss: 337.0983
# Epoch 65 Train RMSE Loss: 33.4170, Val RMSE Loss: 214.4507
# Epoch 66 Train RMSE Loss: 30.3242, Val RMSE Loss: 347.7810
# Epoch 67 Train RMSE Loss: 33.8124, Val RMSE Loss: 329.3862
# Epoch 68 Train RMSE Loss: 31.8868, Val RMSE Loss: 335.3268
# Epoch 69 Train RMSE Loss: 31.5080, Val RMSE Loss: 338.7991
# Epoch 70 Train RMSE Loss: 32.7060, Val RMSE Loss: 354.6211
# Epoch 71 Train RMSE Loss: 45.7733, Val RMSE Loss: 238.3423
# Epoch 72 Train RMSE Loss: 36.2076, Val RMSE Loss: 349.5327
# Epoch 73 Train RMSE Loss: 29.5906, Val RMSE Loss: 331.0126
# Epoch 74 Train RMSE Loss: 27.6096, Val RMSE Loss: 248.6704
# Epoch 75 Train RMSE Loss: 30.1425, Val RMSE Loss: 254.6860
# Epoch 76 Train RMSE Loss: 30.4987, Val RMSE Loss: 340.0211
# Epoch 77 Train RMSE Loss: 63.0560, Val RMSE Loss: 159.0778
# Epoch 78 Train RMSE Loss: 34.3399, Val RMSE Loss: 319.0218
# Epoch 79 Train RMSE Loss: 28.7859, Val RMSE Loss: 310.5614
# Epoch 80 Train RMSE Loss: 28.1788, Val RMSE Loss: 288.8834
# Epoch 81 Train RMSE Loss: 33.9377, Val RMSE Loss: 312.6196
# Epoch 82 Train RMSE Loss: 30.8027, Val RMSE Loss: 205.3310
# Epoch 83 Train RMSE Loss: 27.1448, Val RMSE Loss: 140.2037
# Epoch 84 Train RMSE Loss: 38.6429, Val RMSE Loss: 314.6130
# Epoch 85 Train RMSE Loss: 28.0524, Val RMSE Loss: 249.1089
# Epoch 86 Train RMSE Loss: 30.7217, Val RMSE Loss: 221.3717
# Epoch 87 Train RMSE Loss: 26.6229, Val RMSE Loss: 239.1024
# Epoch 88 Train RMSE Loss: 27.9953, Val RMSE Loss: 306.1604
# Epoch 89 Train RMSE Loss: 32.2713, Val RMSE Loss: 149.3075
# Epoch 90 Train RMSE Loss: 27.4839, Val RMSE Loss: 224.2330
# Epoch 91 Train RMSE Loss: 30.7736, Val RMSE Loss: 147.2468
# Epoch 92 Train RMSE Loss: 28.4542, Val RMSE Loss: 279.0666
# Epoch 93 Train RMSE Loss: 51.9966, Val RMSE Loss: 349.3134
# Epoch 94 Train RMSE Loss: 41.5480, Val RMSE Loss: 343.5277
# Epoch 95 Train RMSE Loss: 26.5589, Val RMSE Loss: 321.3849
# Epoch 96 Train RMSE Loss: 25.8906, Val RMSE Loss: 310.3448
# Epoch 97 Train RMSE Loss: 24.7072, Val RMSE Loss: 340.3921
# Epoch 98 Train RMSE Loss: 29.9495, Val RMSE Loss: 329.1315
# Epoch 99 Train RMSE Loss: 31.3212, Val RMSE Loss: 174.0968
# Epoch 100 Train RMSE Loss: 71.7893, Val RMSE Loss: 351.6024
# Epoch 101 Train RMSE Loss: 36.4131, Val RMSE Loss: 313.8805
# Epoch 102 Train RMSE Loss: 35.0482, Val RMSE Loss: 119.9899
# Epoch 103 Train RMSE Loss: 49.3334, Val RMSE Loss: 319.3640
# Epoch 104 Train RMSE Loss: 28.5006, Val RMSE Loss: 127.3336
# Epoch 105 Train RMSE Loss: 28.5510, Val RMSE Loss: 331.3600
# Epoch 106 Train RMSE Loss: 26.7932, Val RMSE Loss: 341.9606
# Epoch 107 Train RMSE Loss: 28.4925, Val RMSE Loss: 259.5217
# Epoch 108 Train RMSE Loss: 66.3822, Val RMSE Loss: 322.6102
# Epoch 109 Train RMSE Loss: 49.1744, Val RMSE Loss: 317.2458
# Epoch 110 Train RMSE Loss: 34.4573, Val RMSE Loss: 324.8666
# Epoch 111 Train RMSE Loss: 30.0727, Val RMSE Loss: 342.1814
# Epoch 112 Train RMSE Loss: 41.0873, Val RMSE Loss: 267.4901
# Epoch 113 Train RMSE Loss: 46.9540, Val RMSE Loss: 309.5112
# Epoch 114 Train RMSE Loss: 40.7065, Val RMSE Loss: 339.8042
# Epoch 115 Train RMSE Loss: 29.3157, Val RMSE Loss: 320.5358
# Epoch 116 Train RMSE Loss: 24.5738, Val RMSE Loss: 336.3879
# Epoch 117 Train RMSE Loss: 26.8722, Val RMSE Loss: 333.5799
# Epoch 118 Train RMSE Loss: 26.5089, Val RMSE Loss: 337.7193
# Epoch 119 Train RMSE Loss: 36.0700, Val RMSE Loss: 314.6146
# Epoch 120 Train RMSE Loss: 33.7876, Val RMSE Loss: 357.4351
# Epoch 121 Train RMSE Loss: 57.3038, Val RMSE Loss: 358.6269
# Epoch 122 Train RMSE Loss: 27.1602, Val RMSE Loss: 375.0358
# Epoch 123 Train RMSE Loss: 24.8076, Val RMSE Loss: 276.9536
# Epoch 124 Train RMSE Loss: 24.1445, Val RMSE Loss: 263.9820
# Epoch 125 Train RMSE Loss: 24.6236, Val RMSE Loss: 368.8787
# Epoch 126 Train RMSE Loss: 39.3553, Val RMSE Loss: 395.2735
# Epoch 127 Train RMSE Loss: 99.7427, Val RMSE Loss: 411.0089
# Epoch 128 Train RMSE Loss: 36.5857, Val RMSE Loss: 391.0393
# Epoch 129 Train RMSE Loss: 28.8961, Val RMSE Loss: 386.1558
# Epoch 130 Train RMSE Loss: 26.9590, Val RMSE Loss: 389.6208
# Epoch 131 Train RMSE Loss: 36.1863, Val RMSE Loss: 449.0620
