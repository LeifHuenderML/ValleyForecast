# %%
from mlstm import rigid_mLSTM
import torch
from torch.utils.data import DataLoader
import torch.nn as nn

import numpy as np
import time

def trainer(model, epochs, train_loader, val_loader, loss_fn, optim):
    train_losses = []
    val_losses = []
    best_train_loss = float('inf')
    best_val_loss = float('inf')
    best_train_epoch = 0
    best_val_epoch = 0

    for epoch in range(1, epochs+1):
        # Training
        model.train()
        num_batches = len(train_loader)
        total_train_loss = 0
        for x, y in train_loader:
            x, y = x.to('cuda'), y.to('cuda')
            output = model(x)
            loss = loss_fn(output, y)
            optim.zero_grad()
            loss.backward()
            optim.step()
            total_train_loss += loss.item()
        
        avg_train_loss = np.sqrt(total_train_loss / num_batches)
        train_losses.append(avg_train_loss)
        
        if avg_train_loss < best_train_loss:
            best_train_loss = avg_train_loss
            best_train_epoch = epoch

        # Validation
        model.eval()
        num_val_batches = len(val_loader)
        total_val_loss = 0
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to('cuda'), y.to('cuda')
                output = model(x)
                loss = loss_fn(output, y)
                total_val_loss += loss.item()
        
        avg_val_loss = np.sqrt(total_val_loss / num_val_batches)
        val_losses.append(avg_val_loss)
        
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_val_epoch = epoch

        print(f'Epoch {epoch} Train RMSE Loss: {avg_train_loss:.4f}, Val RMSE Loss: {avg_val_loss:.4f}')

        # Save results to a .txt file
        with open('test_1_round_1_training_results.txt', 'w') as f:
            f.write(f'Best Training RMSE Loss: {best_train_loss:.4f} at epoch {best_train_epoch}\n')
            f.write(f'Best Validation RMSE Loss: {best_val_loss:.4f} at epoch {best_val_epoch}\n')
            f.write('\nEpoch-wise losses:\n')
            for epoch, (train_loss, val_loss) in enumerate(zip(train_losses, val_losses), 1):
                f.write(f'Epoch {epoch}: Train RMSE = {train_loss:.4f}, Val RMSE = {val_loss:.4f}\n')

    return train_losses, val_losses, best_train_loss, best_val_loss, best_train_epoch, best_val_epoch


train = torch.load('../../../../data/cleaned/train.pt')
val = torch.load('../../../../data/cleaned/val.pt')
batch_size = 32
train_loader = DataLoader(train, batch_size, shuffle=True, drop_last=True)
val_loader = DataLoader(val, batch_size=32, shuffle=True, drop_last=True)
model = rigid_mLSTM()
model.to('cuda')
loss_fn = torch.nn.MSELoss()
optim = torch.optim.Adam(params=model.parameters(), lr=0.001)

start = time.time()
losses = trainer(model, 1000, train_loader, val_loader, loss_fn, optim)
end = time.time()

print(f'\nTotal training time on 100 epochs: {end-start}')
# Out:
# Epoch 1 Train RMSE Loss: 281.8902, Val RMSE Loss: 136.0428
# Epoch 2 Train RMSE Loss: 279.3211, Val RMSE Loss: 158.4888
# Epoch 3 Train RMSE Loss: 239.5906, Val RMSE Loss: 94.8930
# Epoch 4 Train RMSE Loss: 204.8468, Val RMSE Loss: 94.1529
# Epoch 5 Train RMSE Loss: 162.8093, Val RMSE Loss: 104.9986
# Epoch 6 Train RMSE Loss: 136.5309, Val RMSE Loss: 66.2604
# Epoch 7 Train RMSE Loss: 123.8477, Val RMSE Loss: 120.4880
# Epoch 8 Train RMSE Loss: 108.2315, Val RMSE Loss: 95.7428
# Epoch 9 Train RMSE Loss: 107.2442, Val RMSE Loss: 108.3717
# Epoch 10 Train RMSE Loss: 110.6957, Val RMSE Loss: 105.5441
# Epoch 11 Train RMSE Loss: 86.3667, Val RMSE Loss: 129.1884
# Epoch 12 Train RMSE Loss: 99.8410, Val RMSE Loss: 139.3049
# Epoch 13 Train RMSE Loss: 85.4332, Val RMSE Loss: 128.7029
# Epoch 14 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 15 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 16 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 17 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 18 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 19 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 20 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 21 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 22 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 23 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 24 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 25 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 26 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 27 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 28 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 29 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 30 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 31 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 32 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 33 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 34 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 35 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 36 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 37 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 38 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 39 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 40 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 41 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 42 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 43 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 44 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 45 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 46 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 47 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 48 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 49 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 50 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 51 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 52 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 53 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 54 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 55 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 56 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 57 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 58 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 59 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 60 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 61 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 62 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 63 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 64 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 65 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 66 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 67 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 68 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 69 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 70 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 71 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 72 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 73 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 74 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 75 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 76 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 77 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 78 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 79 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 80 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 81 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 82 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 83 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 84 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 85 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 86 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 87 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 88 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 89 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 90 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 91 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 92 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 93 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 94 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 95 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 96 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 97 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 98 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 99 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 100 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 101 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 102 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 103 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 104 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 105 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 106 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 107 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 108 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 109 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 110 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 111 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 112 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 113 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 114 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 115 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 116 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 117 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 118 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 119 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 120 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 121 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 122 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 123 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 124 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 125 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 126 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 127 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 128 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 129 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 130 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 131 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 132 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 133 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 134 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 135 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 136 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 137 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 138 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 139 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 140 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 141 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 142 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 143 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 144 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 145 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 146 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 147 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 148 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 149 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 150 Train RMSE Loss: nan, Val RMSE Loss: nan
# Epoch 151 Train RMSE Loss: nan, Val RMSE Loss: nan
