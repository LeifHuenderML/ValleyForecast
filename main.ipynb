# %%
import torch

from xlstm import (
    xLSTMBlockStack,
    xLSTMBlockStackConfig,
    mLSTMBlockConfig,
    mLSTMLayerConfig,
    sLSTMBlockConfig,
    sLSTMLayerConfig,
    FeedForwardConfig,
)

cfg = xLSTMBlockStackConfig(
    mlstm_block=mLSTMBlockConfig(
        mlstm=mLSTMLayerConfig(
            conv1d_kernel_size=4, qkv_proj_blocksize=4, num_heads=4
        )
    ),
    slstm_block=sLSTMBlockConfig(
        slstm=sLSTMLayerConfig(
            backend="cuda",
            num_heads=4,
            conv1d_kernel_size=4,
            bias_init="powerlaw_blockdependent",
        ),
        feedforward=FeedForwardConfig(proj_factor=1.3, act_fn="gelu"),
    ),
    context_length=256,
    num_blocks=7,
    embedding_dim=128,
    slstm_at=[1],

)

xlstm_stack = xLSTMBlockStack(cfg)

x = torch.randn(4, 256, 128).to("cuda")
xlstm_stack = xlstm_stack.to("cuda")
y = xlstm_stack(x)
y.shape == x.shape
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_165213/1644843653.py", line 1, in <module>
#     import torch
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/torch/__init__.py", line 1471, in <module>
#     from .functional import *  # noqa: F403
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /home/intellect/anaconda3/envs/xlstm/lib/python3.11/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /opt/conda/conda-bld/pytorch_1704987288773/work/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import torch
# ----> 3 from xlstm import (
#       4     xLSTMBlockStack,
#       5     xLSTMBlockStackConfig,
#       6     mLSTMBlockConfig,
#       7     mLSTMLayerConfig,
#       8     sLSTMBlockConfig,
#       9     sLSTMLayerConfig,
#      10     FeedForwardConfig,
#      11 )
#      13 cfg = xLSTMBlockStackConfig(
#      14     mlstm_block=mLSTMBlockConfig(
#      15         mlstm=mLSTMLayerConfig(
#    (...)
#      32
#      33 )
#      35 xlstm_stack = xLSTMBlockStack(cfg)
#
# ImportError: cannot import name 'xLSTMBlockStack' from 'xlstm' (/home/intellect/Documents/Research/Current/ValleyForecast/xlstm/__init__.py)
